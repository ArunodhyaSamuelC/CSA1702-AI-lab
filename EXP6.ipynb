# %% [markdown]
# <a href="https://colab.research.google.com/github/ArunodhyaSamuelC/CSA1702-AI-lab/blob/main/EXP6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# EXPERIMENT 6
# List Methods: Add, Append, Extend & Delete

my_list = []

my_list.append(1)
print("After append:", my_list)

my_list.extend([2, 3, 4])
print("After extend:", my_list)

my_list.insert(1, 10)
print("After insert:", my_list)

my_list.remove(3)
print("After remove:", my_list)

my_list.pop()
print("After pop:", my_list)

del my_list[0]
print("After del:", my_list)
# Out:
# After append: [1]
# After extend: [1, 2, 3, 4]
# After insert: [1, 10, 2, 3, 4]
# After remove: [1, 10, 2, 4]
# After pop: [1, 10, 2]
# After del: [10, 2]
